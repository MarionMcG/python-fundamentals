# %% [markdown]
# ## Time Series

# %% [markdown]
# Python comes with two packages for time seies, [datetime](https://docs.python.org/2/library/datetime.html) and [time](https://docs.python.org/2/library/time.html). Pandas also comes with [time series functions](https://pandas.pydata.org/pandas-docs/stable/timeseries.html). In examining time series, we may also need numpy.random. We're going to look specifically at the Poisson Distribution, which models the occurance of events in a time interval.

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Example of a Time Series Data Set

# %% [markdown]
# **Knock Airport Hourly Weather Station Data**
#
# Published by: Met Éireann

# %% [markdown]
# This table contains hourly elements for the last 30 years measured at our synoptic station in Knock_Airport, Co Mayo.
#
# The file is updated monthly. Values for each hour may include (depending on the station): Precipitation Amount (mm); Air Temperature (°C); Wet Bulb Air Temperature (°C); Dew Point Air Temperature (°C); Vapour Pressure (hpa); Relative Humidity (%); Mean Sea Level Pressure (hPa); Mean Hourly Wind Speed (kt); Predominant Hourly wind Direction (kt); Synop Code Present Weather; Synop Code Past Weather; Sunshine duration (hours); Visibility (m); Cloud Ceiling Height (100s feet); Cloud Amount (octa).

# %% [markdown]
# [Pandas Documentation for read_csv](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %% [markdown]
# This is a very large data set. I needed to deal with errors, due to the table not beginning until row 24, and warnings. Rather than looking at all 200,000 rows I have only looked at the first 1000 rows of data

# %%
df = pd.read_csv('http://cli.met.ie/cli/climate_data/webdata/hly4935.csv', skiprows=23, low_memory = False, nrows = 1000)

# %%
df['datetime'] = pd.to_datetime(df['date'])

# %% [markdown]
# I've used pd.to_datetime() to ensure my dtype is correct. It was originally an object, but now its datetime64[ns]. Now I've added a new column to my DataFrame, datetime. Now this column is something Pandas can recognize as a Time Series.

# %%
df
# Out:
#                   date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1    31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2    31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3    31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4    31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# 5    31-jul-1996 12:00    0  0.0      0  14.4      0  10.9    7.3    0.0
# 6    31-jul-1996 13:00    0  0.0      0  14.9      0  10.9    6.7    0.0
# 7    31-jul-1996 14:00    0  0.0      0  13.9      0  10.4    6.7    0.0
# 8    31-jul-1996 15:00    0  0.0      0  13.2      0  10.9    8.6    0.0
# 9    31-jul-1996 16:00    0  0.0      0  15.1      0  11.3    7.5    0.0
# 10   31-jul-1996 17:00    0  0.0      0  11.6      0  10.6    9.6    0.0
# 11   31-jul-1996 18:00    0  0.0      0  13.3      0  10.9    8.5    0.0
# 12   31-jul-1996 19:00    0  0.0      0  12.7      0  11.0    9.4    0.0
# 13   31-jul-1996 20:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 14   31-jul-1996 21:00    0  0.0      0  10.9      0  10.2    9.5    0.0
# 15   31-jul-1996 22:00    0  0.0      0  10.8      0  10.1    9.4    0.0
# 16   31-jul-1996 23:00    0  0.0      0   9.6      0   8.8    7.9    0.0
# 17   01-aug-1996 00:00    0  0.0      0   9.7      0   9.0    8.3    0.0
# 996  10-sep-1996 19:00    0  0.0      0  12.8      0  12.0   11.3   13.4
# 997  10-sep-1996 20:00    0  0.0      0  12.4      0  11.7   11.1   13.2
# 998  10-sep-1996 21:00    0  0.0      0  12.2      0  11.6   11.1   13.2
# 999  10-sep-1996 22:00    0  0.0      0  12.0      0  11.4   10.9   13.0
#
#      rhum         ...         wdsp  ind.4 wddir  ww   w  sun    vis  clht  \
# 0       0         ...            0      0     0  25  81  0.0  35000    32
# 1       0         ...            0      0     0  25  82  0.0  40000    45
# 2       0         ...            0      0     0  80  81  0.0   8000    32
# 3       0         ...            0      0     0  25  82  0.0  28000    35
# 4       0         ...            0      0     0   2  11  0.0  40000    40
# 5       0         ...            0      0     0   1  82  0.0  40000    43
# 6       0         ...            0      0     0   2  11  0.0  40000    43
# 7       0         ...            0      0     0   2  11  0.0  50000    45
# 8       0         ...            0      0     0  25  82  0.0   8000    45
# 9       0         ...            0      0     0  25  82  0.0  35000    40
# 10      0         ...            0      0     0   2  11  0.0  35000    40
# 11      0         ...            0      0     0   2  82  0.0  35000    20
# 12      0         ...            0      0     0   2  11  0.0  35000    40
# 13      0         ...            0      0     0  25  82  0.0  35000    40
# 14      0         ...            0      0     0   2  82  0.0  35000    40
# 15      0         ...            0      0     0   2  11  0.0  35000    40
# 16      0         ...            0      0     0   2  11  0.0  35000     0
# 17      0         ...            0      0     0   1  81  0.0  35000   999
# 18     92         ...            6      2   230   2  11  0.0  35000   999
# 19     82         ...            8      2   240   2  11  0.0  35000    50
# 20     87         ...            9      2   250   2  11  0.0  35000    44
# 21     81         ...            8      2   240   2  11  0.0  30000    46
# 22     88         ...            8      2   250   2  11  0.0  30000    40
# 23     87         ...            8      2   250   2  11  0.0  30000    43
# 24     85         ...            7      2   240   2  11  0.0  25000    45
# 25     89         ...           11      2   250   2  11  0.0  30000    42
# 26     83         ...           11      2   250  21  62  0.0  30000    40
# 27     78         ...           13      2   260   2  11  0.0  35000    37
# 28     79         ...           13      2   260  80  22  0.0  22000    33
# 29     74         ...           12      2   270   1  86  0.6  40000    44
# ..    ...         ...          ...    ...   ...  ..  ..  ...    ...   ...
# 970    76         ...           16      2   330   2  11  1.0  50000   999
# 971    81         ...           14      2   330   2  11  0.8  50000   250
# 972    88         ...            8      2   340   2  11  0.0  50000   999
# 973    94         ...            7      2   340   2  11  0.0  40000   999
# 974    91         ...            9      2   360   2  11  0.0  40000   999
# 975    90         ...           10      2   360   2  11  0.0  40000   999
# 976    92         ...           10      2   360   2  11  0.0  40000   999
# 977    92         ...            8      2   360   2  11  0.0  30000    22
# 978    92         ...            8      2   360   2  11  0.0  30000    22
# 979    89         ...            9      2   360   2  11  0.0  30000    22
# 980    89         ...            7      2   360   2  11  0.0  30000    22
# 981    92         ...            5      2   350   2  11  0.0  30000    20
# 982    94         ...            4      2   350   2  11  0.0  30000    20
# 983    96         ...            4      2   340   2  11  0.0  30000    22
# 984    92         ...            6      2   360   2  11  0.2  30000    22
# 985    91         ...            7      2   350   2  11  0.5  25000   999
# 986    81         ...            8      2   350   2  11  0.1  30000    98
# 987    78         ...            8      2   360   2  11  0.5  30000    72
# 988    80         ...            8      2   350   2  11  0.0  25000    19
# 989    94         ...            8      2   350  20  51  0.0  16000    55
# 990    85         ...            9      2   330   2  11  0.0  20000    63
# 991    82         ...            9      2   340   2  11  0.0  30000    62
# 992    77         ...            9      2   340   2  11  0.1  30000    64
# 993    77         ...           10      2   340   2  11  0.1  30000    20
# 994    76         ...           10      2   340   2  11  1.0  30000   999
# 995    84         ...           10      2   340   2  11  0.1  30000    59
# 996    91         ...            9      2   340   2  11  0.0  24000    55
# 997    92         ...            7      2   340   2  11  0.0  24000    34
# 998    93         ...            6      2   340   2  11  0.0  24000    34
# 999    93         ...            7      2   330   2  11  0.0  24000    34
#
#     clamt            datetime
# 0       5 1996-04-10 14:00:00
# 1       5 1996-07-31 08:00:00
# 2       7 1996-07-31 09:00:00
# 3       6 1996-07-31 10:00:00
# 4       6 1996-07-31 11:00:00
# 5       6 1996-07-31 12:00:00
# 6       5 1996-07-31 13:00:00
# 7       6 1996-07-31 14:00:00
# 8       7 1996-07-31 15:00:00
# 9       7 1996-07-31 16:00:00
# 10      7 1996-07-31 17:00:00
# 11      7 1996-07-31 18:00:00
# 12      6 1996-07-31 19:00:00
# 13      6 1996-07-31 20:00:00
# 14      6 1996-07-31 21:00:00
# 15      6 1996-07-31 22:00:00
# 16      3 1996-07-31 23:00:00
# 17      3 1996-08-01 00:00:00
# 18      4 1996-08-01 01:00:00
# 19      5 1996-08-01 02:00:00
# 20      5 1996-08-01 03:00:00
# 21      6 1996-08-01 04:00:00
# 22      7 1996-08-01 05:00:00
# 23      7 1996-08-01 06:00:00
# 24      7 1996-08-01 07:00:00
# 25      7 1996-08-01 08:00:00
# 26      7 1996-08-01 09:00:00
# 27      7 1996-08-01 10:00:00
# 28      7 1996-08-01 11:00:00
# 29      6 1996-08-01 12:00:00
# ..    ...                 ...
# 970     2 1996-09-09 17:00:00
# 971     5 1996-09-09 18:00:00
# 972     2 1996-09-09 19:00:00
# 973     2 1996-09-09 20:00:00
# 974     1 1996-09-09 21:00:00
# 975     1 1996-09-09 22:00:00
# 976     1 1996-09-09 23:00:00
# 977     5 1996-09-10 00:00:00
# 978     6 1996-09-10 01:00:00
# 979     7 1996-09-10 02:00:00
# 980     7 1996-09-10 03:00:00
# 981     6 1996-09-10 04:00:00
# 982     6 1996-09-10 05:00:00
# 983     6 1996-09-10 06:00:00
# 984     5 1996-09-10 07:00:00
# 985     4 1996-09-10 08:00:00
# 986     7 1996-09-10 09:00:00
# 987     6 1996-09-10 10:00:00
# 988     8 1996-09-10 11:00:00
# 989     8 1996-09-10 12:00:00
# 990     8 1996-09-10 13:00:00
# 991     7 1996-09-10 14:00:00
# 992     7 1996-09-10 15:00:00
# 993     7 1996-09-10 16:00:00
# 994     4 1996-09-10 17:00:00
# 995     7 1996-09-10 18:00:00
# 996     7 1996-09-10 19:00:00
# 997     7 1996-09-10 20:00:00
# 998     7 1996-09-10 21:00:00
# 999     7 1996-09-10 22:00:00
#
# [1000 rows x 22 columns]

# %% [markdown]
# ### Plotting data from my DataFrame

# %%
sns.lineplot(x = 'datetime', y = 'temp', data = df);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-e35ffe452204> in <module>()
# ----> 1 sns.lineplot(x = 'datetime', y = 'temp', data = df);
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'
